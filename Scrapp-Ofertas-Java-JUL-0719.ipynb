# %% [markdown]
# # Scrapp-Ofertas-Java-JUL-0719 Portales de Empleo
#
# Portales Trabajando Computrabajo, Workib

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
df_TC = pd.read_csv('data/mTRCa-java.csv', encoding='latin-1', low_memory=False)
df_CT = pd.read_csv('data/mCTa-java.csv', encoding='latin-1', low_memory=False)
df_WK = pd.read_csv('data/ofertaWorKib.csv', encoding='latin-1',low_memory=False)

# %%
#df_TC.shape

# %% [markdown]
# # Trabajando.com
#
# https://www.trabajando.cl/trabajo-empleo/region-metropolitana-de-santiago-java/0aA-LB4Zpd1zBnKEnVkVVK6LuDlUQZPzS_h9G236fV2oxwAIQYqAcEc8g_TZG2Ld-dPXV4QYHlasEdnUYDo0Q-OK5MzfeYUynBFxHYumyoSmLmvSx7EACZ29jTVEOqje?page=11

# %%
df_TC.head(200)
# Out:
#                                                 oferta  \
# 0         (KS) Ingeniero Desarrollador Java/Huechuraba
# 1                               Java Software Engineer
# 2    Analista programador Java Spring Apache Maven ...
# 3    Analista desarrollador Java base de datos meto...
# 4                       Desarrolladores Java y Node JS
# 5    Analista Desarrollador Java experiencia en Mic...
# 6    Analista Desarrollador Java AngularJS J2EE y O...
# 7    Desarrollador Java JavaScript y metodologías á...
# 8    INGENIEROS DE DESARROLLO PLENO JAVA 7 SOAP RES...
# 9                    (MA) Ingeniero Desarrollador Java
# 10                                (MJA) Ingeniero JAVA
# 11                     Ingeniero en Informática (Java)
# 12         Analista Desarrollador Java J2EE Oracle ADF
# 13       Analista Programador JAVA ORACLE JEE Weblogic
# 14   Desarrollador JAVA Oracle Soap JSP Angular Ecl...
# 15      Analista  Programador Java JEE base datos Sql
# ...

# %%
#df_TC.columns

# %%
#df_CT.shape

# %% [markdown]
# # Computrabajo
#
#
# https://www.computrabajo.cl/trabajo-de-JAVA

# %%
df_CT.head(20)
# Out:
#                                          skillempresa  \
# 0   Importante empresa financiera requiere Analist...
# 1   Empresa que presta servicios a grandes cliente...
# 2                         Buscamos Ingenierio en Java
# 3   En Atianza estamos en búsqueda de un ingeniero...
# 4   Importante Empresa Líder de Mercado en Tecnolo...
# 5   En Emergya Chile nos encontramos en la búsqued...
# 6   Reconocido Holding con más de 20 años de prese...
# 7   Reconocida empresa de Tecnología ubicada en Sa...
# 8                   Para importante proyecto bancario
# 9                                  Reconocida empresa
# 10  Reconocido Holding con más de 20 años de prese...
# 11  Nos encontramos en la búsqueda de un Analista ...
# 12  En Zenta Group estamos en la búsqueda de un De...
# 13  Empresa de desarrollo de software busca a Arqu...
# 14                   Somos facilitadores tecnológicos
# 15  para importante entidad financiera ubicada en ...
# ...

# %%
#df_CT .columns

# %%
#df_WK.shape

# %% [markdown]
# # WorKib
#
# https://www.workib.cl/

# %%
df_WK.head(10)
# Out:
#                                          skill  \
# 0                    Analista QA Automatizador
# 1                           Soporte Office 365
# 2                         Analista QA Recoleta
# 3                  Desarrollador Java Santiago
# 4  Jefe De Proyectos TI Exp. Metodologia PMBOK
# 5               Analista Bilingüe ERP Netsuite
# 6       Analista de Procesos senior Las Condes
# 7            Desarrollador Mobile React Native
# 8         Analista Desarrollador Java Santiago
# 9   Ingeniero de Software Bilingüe Providencia
#
#                                               oferta
# 0  Prestigiosa empresa del rubro Bancario requier...
# 1  Prestigiosa empresa del rubro industria requie...
# 2  Buscamos profesionales enfocados en el trabajo...
# 3  Buscamos profesionales proactivos para el carg...
# 4  Prestigiosa empresa del rubro educacional requ...
# 5  Prestigiosa empresa del rubro tecnologia y com...
# 6  Buscamos profesionales Autónomos metódicos y o...
# ...

# %%
df_WK.columns
# Out:
# Index(['skill', 'oferta'], dtype='object')
